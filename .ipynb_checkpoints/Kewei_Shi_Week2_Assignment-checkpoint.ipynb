# %% [markdown]
# ALY6140 Week2 Assignment
# Written by Kewei Shi
#
# Assignment 2 Steps:
# 1. Create a Jupyter notebook file;
# 2. Write codes to read different example files (Example_Image, Example_Csv, Example_Excel, Example_Binary);
# 3. write function to manipulate read files;
# 4. Provide explanation about each file in a markdown section;
# 5. Submit assignment to github branch.

# %%
#Import useful libraries
import pandas as pd
import numpy as np

# %%
from PIL import Image, ImageFilter     #Read image
image = Image.open('/Users/r/Desktop/School./ALY6140/ALY6140/Assignment2/Nuclei_Msk.jpg') 
image.show()     #Display Image

# %%
df = pd.read_csv('/Users/r/Desktop/School./ALY6140/ALY6140/Assignment2/Nuclei.csv')   
df   #Read CSV File
# Out:
#       ImageNumber  ObjectNumber  Intensity_IntegratedIntensityEdge_DAPI  \
# 0               1             1                                5.066987
# 1               1             2                                4.461616
# 2               1             3                                4.838346
# 3               1             4                                3.235828
# 4               1             5                                3.967391
# 5               1             6                                3.642588
# 6               1             7                                4.316793
# 7               1             8                                4.867002
# 8               1             9                                3.629191
# 9               1            10                                5.247822
# 10              1            11                                5.795468
# 11              1            12                                5.457908
# ...
