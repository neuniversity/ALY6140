# %%
###open the Nuclei_Msk.jpg



from PIL import Image

img = Image.open('Nuclei_Msk.jpg')
img.show()

###Resize the image.

basewidth = 300
wpercent = (basewidth/float(img.size[0]))
hsize = int((float(img.size[1])*float(wpercent)))
img = img.resize((basewidth,hsize), Image.ANTIALIAS)
img.save('Nuclei_Msk_Resize.jpg')

# %%
###Open the Nuclei.csv in pandas dataframe.

import pandas as pd

Nuclei = pd.read_csv('Nuclei.csv')
print(f'There are {Nuclei.shape[1]} columns and {Nuclei.shape[0]} rows in the dataset.')

###Print the first 10 rows.
Nuclei.head(10)
# Out:
# There are 33 columns and 1244 rows in the dataset.
#    ImageNumber  ObjectNumber  Intensity_IntegratedIntensityEdge_DAPI  \
# 0            1             1                                5.066987
# 1            1             2                                4.461616
# 2            1             3                                4.838346
# 3            1             4                                3.235828
# 4            1             5                                3.967391
# 5            1             6                                3.642588
# 6            1             7                                4.316793
# 7            1             8                                4.867002
# 8            1             9                                3.629191
# 9            1            10                                5.247822
#
#    Intensity_IntegratedIntensityEdge_PI  Intensity_IntegratedIntensity_DAPI  \
# 0                              4.504585                           63.661448
# 1                              3.758312                           52.943389
# 2                              2.810544                           31.127337
# 3                              3.306371                           38.797894
# 4                              3.223301                           37.443107
# 5                              3.405142                           41.364141
# 6                              4.477180                           31.367926
# 7                              4.065171                           76.837522
# 8                              3.643809                           38.937820
# 9                              4.037842                           50.699672
#
#    Intensity_IntegratedIntensity_PI  Intensity_LowerQuartileIntensity_DAPI  \
# 0                         26.980835                               0.060006
# 1                         20.978958                               0.055276
# 2                         12.375784                               0.064607
# 3                         18.318380                               0.040070
# 4                         15.369772                               0.056352
# 5                         16.970337                               0.044755
# 6                         23.820432                               0.041352
# 7                         25.455009                               0.060227
# 8                         19.525383                               0.049371
# 9                         22.240864                               0.055512
#
#    Intensity_LowerQuartileIntensity_PI  Intensity_MADIntensity_DAPI  \
# 0                             0.035172                     0.019913
# 1                             0.033928                     0.033433
# 2                             0.030098                     0.014519
# 3                             0.032624                     0.028779
# 4                             0.032898                     0.027031
# 5                             0.032547                     0.034653
# 6                             0.034897                     0.006256
# 7                             0.033768                     0.044175
# 8                             0.033719                     0.016052
# 9                             0.033833                     0.024109
#
#    Intensity_MADIntensity_PI          ...           \
# 0                   0.001007          ...
# 1                   0.001694          ...
# 2                   0.000992          ...
# 3                   0.000977          ...
# 4                   0.001404          ...
# 5                   0.001190          ...
# 6                   0.000870          ...
# 7                   0.001801          ...
# 8                   0.000931          ...
# 9                   0.001350          ...
#
#    Intensity_MinIntensityEdge_PI  Intensity_MinIntensity_DAPI  \
# 0                       0.031388                     0.031815
# 1                       0.028016                     0.029816
# 2                       0.027512                     0.038941
# 3                       0.028748                     0.026749
# 4                       0.028244                     0.031708
# 5                       0.030655                     0.028626
# 6                       0.032563                     0.026078
# 7                       0.027161                     0.031449
# 8                       0.031189                     0.026932
# 9                       0.029801                     0.033814
#
#    Intensity_MinIntensity_PI  Intensity_StdIntensityEdge_DAPI  \
# 0                   0.031388                         0.005757
# 1                   0.027481                         0.005620
# 2                   0.027512                         0.007579
# 3                   0.028748                         0.003096
# 4                   0.028153                         0.005773
# 5                   0.029587                         0.004644
# 6                   0.032166                         0.007047
# 7                   0.027161                         0.006060
# 8                   0.031006                         0.004834
# 9                   0.029801                         0.005416
#
#    Intensity_StdIntensityEdge_PI  Intensity_StdIntensity_DAPI  \
# 0                       0.001566                     0.029094
# 1                       0.002464                     0.036908
# 2                       0.001566                     0.019099
# 3                       0.001483                     0.030482
# 4                       0.002650                     0.030331
# 5                       0.001792                     0.037384
# 6                       0.001322                     0.009035
# 7                       0.002904                     0.049777
# 8                       0.001657                     0.023147
# 9                       0.001868                     0.027369
#
#    Intensity_StdIntensity_PI  Intensity_UpperQuartileIntensity_DAPI  \
# 0                   0.001507                               0.107881
# 1                   0.002593                               0.121820
# 2                   0.001467                               0.092367
# 3                   0.001442                               0.096674
# 4                   0.002118                               0.110895
# 5                   0.001684                               0.113855
# 6                   0.001290                               0.053887
# 7                   0.002442                               0.149538
# 8                   0.001468                               0.086091
# 9                   0.001969                               0.103613
#
#    Intensity_UpperQuartileIntensity_PI  Number_Object_Number
# 0                             0.037224                     1
# 1                             0.037316                     2
# 2                             0.032090                     3
# 3                             0.034585                     4
# 4                             0.035672                     5
# 5                             0.034943                     6
# 6                             0.036652                     7
# 7                             0.037415                     8
# 8                             0.035573                     9
# 9                             0.036481                    10
#
# [10 rows x 33 columns]

# %%
###Open the 16o03002.abf

import pyabf

abf = pyabf.ABF("16o03002.abf")
print(abf)

# %%
###Plot the sweep data.

import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
for sweepNumber in range(abf.sweepCount)[::1]:
    abf.setSweep(sweepNumber)
    plt.plot(abf.sweepX,abf.sweepY,alpha=.5,label=f"sweep {sweepNumber+1}")

plt.margins(0, .1)
plt.legend()
plt.ylabel(abf.sweepLabelY)
plt.xlabel(abf.sweepLabelX)
plt.title(abf.abfID)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4ae4b4e1f1f5> in <module>()
#       4
#       5 plt.figure(figsize=(8, 5))
# ----> 6 for sweepNumber in range(abf.sweepCount)[::1]:
#       7     abf.setSweep(sweepNumber)
#       8     plt.plot(abf.sweepX,abf.sweepY,alpha=.5,label=f"sweep {sweepNumber+1}")
#
# NameError: name 'abf' is not defined

# %%
import pyabf
import matplotlib.pyplot as plot
abf_plot = pyabf.ABF('16o03002.abf')
abf.setSweep(0)
plot.figure(figsize=(10, 5))
plot.plot(abf.sweepX, abf.sweepY, lw=.5)
plot.show()     #Plot the first sweep of .abf file
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-25f8f14b6165> in <module>()
# ----> 1 import pyabf
#       2 import matplotlib.pyplot as plot
#       3 abf_plot = pyabf.ABF('16o03002.abf')
#       4 abf.setSweep(0)
#       5 plot.figure(figsize=(10, 5))
#
# ModuleNotFoundError: No module named 'pyabf'
