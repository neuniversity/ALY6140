# %% [markdown]
# # Week 2_Assignment
#
# By Canlin Jiang

# %% [markdown]
# ## Part 1. Example_Image
#
# In this part, we need to
#     1. Read the image by import PIL.
#     2. Change the size of the image.

# %%
###Open the Nuclei_Msk.jpg

from PIL import Image

img = Image.open('Nuclei_Msk.jpg')
img.show()

###Resize the image.

basewidth = 300
wpercent = (basewidth/float(img.size[0]))
hsize = int((float(img.size[1])*float(wpercent)))
img = img.resize((basewidth,hsize), Image.ANTIALIAS)
img.save('Nuclei_Msk_Resize.jpg') 

img.show()

# %% [markdown]
# In this part, we diminished image into basewidth of 300, and save he change into a new file, which is named Nuclei_Msk_Resize.jpg.

# %% [markdown]
# ## Part 2. Example_CSV
#
# In this part, we need to
#
#     1.Install the pandas as pd to shape the dataset.
#     2.Print the first 10 rows.

# %%
###Open the Nuclei.csv in pandas dataframe.

import pandas as pd

Nuclei = pd.read_csv('Nuclei.csv')
print(f'There are {Nuclei.shape[1]} columns and {Nuclei.shape[0]} rows in the dataset.')

###Print the first 10 rows.
Nuclei.head(10)
# Out:
# There are 33 columns and 1244 rows in the dataset.
#    ImageNumber  ObjectNumber  Intensity_IntegratedIntensityEdge_DAPI  \
# 0            1             1                                5.066987
# 1            1             2                                4.461616
# 2            1             3                                4.838346
# 3            1             4                                3.235828
# 4            1             5                                3.967391
# 5            1             6                                3.642588
# 6            1             7                                4.316793
# 7            1             8                                4.867002
# 8            1             9                                3.629191
# 9            1            10                                5.247822
#
#    Intensity_IntegratedIntensityEdge_PI  Intensity_IntegratedIntensity_DAPI  \
# 0                              4.504585                           63.661448
# ...

# %% [markdown]
# In this part, we shaped the dataset into pandas dataframe, which is easier for us to manipulate in python. From the output, we know that there are 33 columns and 1244 rows in the dataset.

# %% [markdown]
# ## Part 3. Example_Binary
#
# In this part, we need to
#     1. Read the .adf files by import pyabf.
#     2. Plot the sweep data.
#     3. Plot Multi-Channel ABFs.

# %% [markdown]
# ### 3.1 Open the 16o03002.abf

# %%
###Open the 16o03002.abf

import pyabf

abf = pyabf.ABF("16o03002.abf")
print(abf)
# Out:
# ABF file (16o03002.abf) with 2 channels, 6 sweeps, and a total length of 0.10 min.

# %% [markdown]
# ### 3.2 Plot the sweep data.

# %%
###Plot the sweep data.

import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
for sweepNumber in range(abf.sweepCount)[::1]:
    abf.setSweep(sweepNumber)
    plt.plot(abf.sweepX,abf.sweepY,alpha=.5,label=f"sweep {sweepNumber+1}")

plt.margins(0, .1)
plt.legend()
plt.ylabel(abf.sweepLabelY)
plt.xlabel(abf.sweepLabelX)
plt.title(abf.abfID)
plt.tight_layout()
plt.show()

# %% [markdown]
# From the plot, we can see that
#     1. At time near 0.1~0.2, the sheep 5 & 6 have two sharp increase of membrane potential which is approximate 20mV.
#     2. At time near 0.2, the sheep 1, 2, 3 and 4 have a mild increase of membrane potential which is approximate between (-60,-50)mV.

# %% [markdown]
# ### 3.3 Plot Multi-Channel ABFs

# %%
###Plot Multi-Channel ABFs


fig = plt.figure(figsize=(8, 5))

abf.setSweep(sweepNumber=0, channel=0)
ax1 = fig.add_subplot(211)
ax1.set_title(f"Channel {abf.sweepChannel+1}")
ax1.plot(abf.sweepX, abf.sweepY, lw=.5)
ax1.set_ylabel(abf.sweepLabelY)

abf.setSweep(sweepNumber=0, channel=1)
ax2 = fig.add_subplot(212)
ax2.set_title(f"Channel {abf.sweepChannel+1}")
ax2.plot(abf.sweepX, abf.sweepY, lw=.5)
ax2.set_xlabel(abf.sweepLabelX)
ax2.set_ylabel(abf.sweepLabelY)

fig.subplots_adjust(hspace=.4)  # add more space between the subplots

plt.show()

# %% [markdown]
# From the plot of two channels, we can know that
#     1. The average membrane potential start to increase near 0.1 second and reach the peak near 0.15 second.
#     2. The clamp current ranges from -2pA to 4pA.

# %% [markdown]
# ## Part 4. Example_Excel
#
# In this part, we need to
#     1. Read the example excel, and shape it into pandas dataframe.
#     2. Print the first 10 rows.
#     3. Try the linear regression between Units Sold and Profit.
#     4. Find the relationship of products' profit in different segments and different countries.

# %% [markdown]
# ### 4.1 Load the excel and print the first 10 rows

# %%
###Open the Financial Sample.xlsx

import xlrd

Financial = pandas.read_excel('Financial Sample.xlsx')
print(f'There are {Financial.shape[1]} columns and {Financial.shape[0]} rows in the dataset.')

###Print the first 10 rows.
Financial.head(10)
# Out:
# There are 16 columns and 700 rows in the dataset.
#             Segment  Country    Product Discount Band  Units Sold  \
# 0        Government   Canada  Carretera          None      1618.5
# 1        Government  Germany  Carretera          None      1321.0
# 2         Midmarket   France  Carretera          None      2178.0
# 3         Midmarket  Germany  Carretera          None       888.0
# 4         Midmarket   Mexico  Carretera          None      2470.0
# 5        Government  Germany  Carretera          None      1513.0
# 6         Midmarket  Germany    Montana          None       921.0
# 7  Channel Partners   Canada    Montana          None      2518.0
# 8        Government   France    Montana          None      1899.0
# 9  Channel Partners  Germany    Montana          None      1545.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 0                    3          20      32370.0        0.0   32370.0
# ...

# %% [markdown]
# From the dataset, we could see that there might be a linear relationship between Units Sold and Profit, so we could try to plot a line to see if the linear linear relationship exists.
#
# Futhure more, from the first three columns, we can see that the different products are sold in different segments, different countries. Therefore, we could figure out if there are any relationships among them.

# %% [markdown]
# ### 4.2 Plot the linear regression between Units Sold and Profit.

# %%
###Show the linear relationship between Units Sold and Profit.

import seaborn as sns

sns.lmplot(x="Units Sold",y="Profit",data=Financial)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# From the scatterplot, we can see the data is so dispersed, so we might need a data cleansing here. But there is still a trend line here, which we could see that as the units sold increases, the profit increases.
#
# In my opinion, the basic trend direction is right here, which is that two factors are positively correlated, but the detailed trend is not trustful. It still need data cleansing at least.

# %% [markdown]
# ### 4.3 Find the relationship of products' profit in different segments and different countries.

# %%
###Plot the relationship of products' profit in different segments and different countries.

sns.factorplot(x="Country", y="Profit",hue="Segment", col="Product", data=Financial, kind="box", 
              palette="Set3");
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# The plot is a mess here. For the reason that there are so many parameters involved here, it's hard to extract information. Therefore, let's decompose the graph.

# %% [markdown]
# #### 4.3.1 Build the boxplot of different products.

# %%
###Build the boxplot of different products.

sns.set_style("whitegrid")
Product_boxplot = sns.boxplot(x="Product", y="Profit",data=Financial, palette="Set3")

# %% [markdown]
# From the boxplot, we can see that VTT has the highest mean of profit, and Velo has the lowest mean of profit.

# %% [markdown]
# #### 4.3.2 Build the boxplot of different countries.

# %%
####Build the boxplot of different countries.

Country_boxplot = sns.boxplot(x="Country", y="Profit",data=Financial, palette="Set2")

# %% [markdown]
# From the boxplot, we can see that Canada has the highest mean of profit, and Mexico has the lowest mean of profit.

# %% [markdown]
# #### 4.3.3 Build the boxplot by different segments.

# %%
###Build the boxplot by different segments.

Segment_boxplot = sns.boxplot(x="Segment", y="Profit",data=Financial, palette="Set1")

# %% [markdown]
# From the boxplot, we can see that small business has the highest mean of profit, and enterprise has the lowest mean of profit. The average profit of goverment and channel partners is similar.

# %% [markdown]
# #### 4.3.4 Build the barplot to show the relationship of products' profit in different segments and different countries.

# %%
###The barplot of products in different countries

Product_By_Country_Barplot = sns.FacetGrid(Financial, col="Product", size=4)
Product_By_Country_Barplot.map(sns.barplot, "Country", "Profit");
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# From the barplot, we can see that
#     1. For carretera, Canada has the lowest profit, Germany has the highest profit.
#     2. For montana, Mexico has the lowest profit, Fance has the highest profit.
#     3. For paseo, Germany has the lowest profit, France has the highest profit.
#     4. For velo, France has the lowest profit, Germany has the highest profit.
#     5. For VTT, France has the lowest profit, Germany has the highest profit.
#     6. For Amarilla, United States of America has the lowest profit, France has the highest profit.
#
# All in all, the products' profit depends on the types themselves and the the countries they were sold.

# %%
###The barplot of products in different segments

Product_By_Segment_Barplot = sns.FacetGrid(Financial, col="Product", size=4)
Product_By_Segment_Barplot.map(sns.barplot, "Segment", "Profit");
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:715: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# From the barplot, we can see that
#     1. For carretera, midmarket was actually losing money, while government maintains the highest profit.
#     2. For montana, midmarket was still losing money, while small business has the highest profit.
#     3. For paseo, small business was losing money, while midmarket has the highest profit.
#     4. For velo, channel partners was losing money, while goverment has the highest profit.
#     5. For VTT, small business  was losing money, while goverment has the highest profit.
#     6. For Amarilla, enterprise was losing money, while goverment has the highest profit.
#
# In conclusion, for different products, the suitable selling channels are extremely important. If we chose the not match channels, as we saw, we might lost money. Further more, the goverment is always a good way for at least, it never shows loss until now.
