# %% [markdown]
# # Week 2 Assignment - Trupti Shah

# %%
import pandas as pd
import seaborn as sns
from PIL import Image, ImageFilter
import pyabf
import csv 
import matplotlib.pyplot as plt

# %% [markdown]
# ### --------------- CSV File ---------------

# %% [markdown]
# #### Reading a csv file -

# %%
Nuclei_csv = pd.read_csv('/Users/Trupti/Desktop/Analytics/ALY6140/Week2Data/Nuclei.csv')

# %% [markdown]
# #### Reading the top 5 rows of the Nuclei.csv file -

# %%
Nuclei_csv.head(5)
# Out:
#    ImageNumber  ObjectNumber  Intensity_IntegratedIntensityEdge_DAPI  \
# 0            1             1                                5.066987
# 1            1             2                                4.461616
# 2            1             3                                4.838346
# 3            1             4                                3.235828
# 4            1             5                                3.967391
#
#    Intensity_IntegratedIntensityEdge_PI  Intensity_IntegratedIntensity_DAPI  \
# 0                              4.504585                           63.661448
# 1                              3.758312                           52.943389
# 2                              2.810544                           31.127337
# 3                              3.306371                           38.797894
# 4                              3.223301                           37.443107
#
#    Intensity_IntegratedIntensity_PI  Intensity_LowerQuartileIntensity_DAPI  \
# ...

# %% [markdown]
# ##### Knowing the number of columns -

# %%
Num_cols = len (Nuclei_csv.columns)
Num_cols
# Out:
# 33

# %% [markdown]
# This means that the data file has 33 columns.

# %% [markdown]
# #### Dropping a column

# %%
#'Number_Object_Number' is repeated twice in the data. Therefore, dropping the 'Number_Object_Number'
Nuclei = Nuclei_csv.drop(['Number_Object_Number'],axis=1)
Num_cols = len (Nuclei.columns)
print(Num_cols)
# Out:
# 32

# %% [markdown]
# After dropping a column we have 33-1=32 columns

# %% [markdown]
# #### Knowing the datatypes of the columns-

# %%
print(Nuclei_csv['ObjectNumber'].dtypes)
print(Nuclei_csv['Intensity_IntegratedIntensityEdge_DAPI'].dtypes)
# Out:
# int64
# float64

# %% [markdown]
# #### Round 'Intensity_IntegratedIntensityEdge_DAPI' column values to 4 decimal values -

# %%
# rounding the values to 4 decimal values
Neu_round = round(Nuclei_csv['Intensity_IntegratedIntensityEdge_DAPI'],4)
Neu_round.head(5)
# Out:
# 0    5.0670
# 1    4.4616
# 2    4.8383
# 3    3.2358
# 4    3.9674
# Name: Intensity_IntegratedIntensityEdge_DAPI, dtype: float64

# %% [markdown]
# ### --------------- Excel File ---------------

# %% [markdown]
# #### Reading a excel file:

# %%
Financial_Excel = pd.read_excel('/Users/Trupti/Desktop/Analytics/ALY6140/Week2Data/Financial Sample.xlsx')

# Reading the top 5 rows
Financial_Excel.head(5)
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %% [markdown]
# #### Specifying and reading a perticular sheet from excel workbook, and skipping the last rows from the excel -

# %%
# sheet_name = 'Sheet1' & skipping last 15 rows
Fin_Sheet2 = pd.read_excel('/Users/Trupti/Desktop/Analytics/ALY6140/Week2Data/Financial Sample.xlsx', sheet_name = 'Sheet1', skipfooter=15)
Fin_Sheet2.head(5)
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %% [markdown]
# #### Renaming the column names -

# %%
# converting 'Fin_Sheet2' to a dataframe
df = pd.DataFrame(Fin_Sheet2)

# renaming second and third columns
df.rename(columns = {'Country':'Country Name', 'Product':'Product Name'})
# Out:
#               Segment              Country Name Product Name Discount Band  \
# 0          Government                    Canada    Carretera          None
# 1          Government                   Germany    Carretera          None
# 2           Midmarket                    France    Carretera          None
# 3           Midmarket                   Germany    Carretera          None
# 4           Midmarket                    Mexico    Carretera          None
# 5          Government                   Germany    Carretera          None
# 6           Midmarket                   Germany      Montana          None
# 7    Channel Partners                    Canada      Montana          None
# 8          Government                    France      Montana          None
# 9    Channel Partners                   Germany      Montana          None
# 10          Midmarket                    Mexico      Montana          None
# ...

# %% [markdown]
# #### Visualization : Let us see the products profit distribution with respect to Country -

# %%
sns.set_style('whitegrid')

# increasing the size of the plot
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 12
fig_size[1] = 12

# creating bar plot
sns.barplot(x='Profit', y='Product', hue='Country', data=Financial_Excel)
# Out:
# /Users/Trupti/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### --------------- Image File ---------------

# %% [markdown]
# #### Reading a .jpg file:

# %%
# Read image
image_jpg = ('/Users/Trupti/Desktop/Analytics/ALY6140/Week2Data/Nuclei_Msk.jpg')
image = Image.open(image_jpg)
#Display image
image.show()

# %% [markdown]
# #### Retrieving size of the given image -

# %%
with Image.open(image_jpg) as image: 
    width, height = image.size
print ('Width of the image is:', width)
print ('Height of the image is:', height)
# Out:
# Width of the image is: 696
# Height of the image is: 520

# %% [markdown]
# #### Rotating the image -

# %%
def rotate(): 
    try: 
        image = Image.open(image_jpg)
        # Angle given 
        image = image.rotate(180)  
        # Saved in the same relative location 
        image.save("rotated_image.jpg") 
    except IOError: 
        pass
  
if __name__ == "__main__": 
    rotate()

# %% [markdown]
# #### Resizing the image -

# %%
def resize(): 
    try: 
        image = Image.open(image_jpg)
   
        img = image.resize((500, 400))  
        #Saved in the same relative location 
        img.save("resized_image.jpg")  
    except IOError: 
        pass
  
if __name__ == "__main__": 
    resize()

# %% [markdown]
# #### Cropping the image -

# %%
def crop(): 
    try: 
        image = Image.open(image_jpg) 
          
        area = (0, 0, width/2, height/2) 
        image = image.crop(area) 
          
        #Saved in the same relative location 
        image.save("cropped_image.jpg")  
          
    except IOError: 
        pass
  
if __name__ == "__main__": 
    crop()

# %% [markdown]
# #### Transposing the image -

# %%
def transpose(): 
    try: 
        image = Image.open(image_jpg) 
          
        #transposing image  
        transposed_img = image.transpose(Image.FLIP_LEFT_RIGHT) 
          
        #Save transposed image 
        transposed_img.save("transposed_image.jpg") 
    except IOError: 
        pass
  
if __name__ == "__main__": 
    transpose()

# %% [markdown]
# #### Pasting an image on another image -

# %%
def overlapping(): 
    try: 
        image1 = Image.open(image_jpg)  
          
        #Relative Path 
        #Image which we want to paste 
        image2_png = ('/Users/Trupti/Desktop/Analytics/ALY6140/Week2Data/image2.png')
        image2 = Image.open(image2_png)  
        image1.paste(image2, (50, 50)) 
          
        #Saved in the same relative location 
        image1.save("overlapped_image.jpg") 
        
        #Display image
        image1.show()
          
    except IOError: 
        pass
  
if __name__ == "__main__": 
    overlapping()

# %% [markdown]
# ### --------------- Binary File ---------------

# %% [markdown]
# #### Read an Axon Binary Format (.abf) file

# %%
abf = pyabf.ABF('/Users/Trupti/Desktop/Analytics/ALY6140/Week2Data/16o03002.abf')
print(abf)
# Out:
# ABF file (16o03002.abf) with 2 channels, 6 sweeps, and a total length of 0.10 min.

# %% [markdown]
# #### Access Sweep Data -

# %%
abf.setSweep(3) # sweeps start at 0
print(abf.sweepY) # sweep data (ADC)
print(abf.sweepC) # sweep command (DAC)
print(abf.sweepX) # sweep times (seconds)
# Out:
# [-61.9812   -61.73706  -62.042236 ... -61.76758  -61.9812   -61.798096]
# [nan nan nan ... nan nan nan]
# [0.000e+00 1.000e-04 2.000e-04 ... 9.997e-01 9.998e-01 9.999e-01]

# %% [markdown]
# #### Let's see some class variables -

# %%
DateTime = abf.abfDateTime
print(DateTime)
path = abf.abfFilePath
print(path)
dataRate = abf.dataRate
print(dataRate)
data = abf.dataSecPerPoint
print(data)
print(abf.sweepLabelX)
print(abf.sweepLabelY)
# Out:
# 2016-10-03 13:16:41.004000
# /Users/Trupti/Desktop/Analytics/ALY6140/Week2Data/16o03002.abf
# 10000
# 0.0001
# time (seconds)
# Clamp Current (pA)

# %% [markdown]
# #### Plotting a Single Sweep -

# %%
abf.setSweep(3)
plt.plot(abf.sweepX, abf.sweepY, lw=.5)
plt.show()

# %% [markdown]
# #### Creating Plots with Matplotlib -

# %%
plt.figure(figsize=(8, 5))
for sweepNumber in range(abf.sweepCount)[::5]:
    abf.setSweep(sweepNumber)
    plt.plot(abf.sweepX,abf.sweepY,alpha=.5,label=f"sweep {sweepNumber+1}")

plt.margins(0, .1)
plt.legend()
plt.ylabel(abf.sweepLabelY)
plt.xlabel(abf.sweepLabelX)
plt.title(abf.abfID)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Plotting Multi-Channel ABFs -

# %%
fig = plt.figure(figsize=(8, 5))

abf.setSweep(sweepNumber=0, channel=0)
ax1 = fig.add_subplot(211)
ax1.set_title(f"Channel {abf.sweepChannel+1}")
ax1.plot(abf.sweepX, abf.sweepY, lw=.5)
ax1.set_ylabel(abf.sweepLabelY)

abf.setSweep(sweepNumber=0, channel=1)
ax2 = fig.add_subplot(212)
ax2.set_title(f"Channel {abf.sweepChannel+1}")
ax2.plot(abf.sweepX, abf.sweepY, lw=.5)
ax2.set_xlabel(abf.sweepLabelX)
ax2.set_ylabel(abf.sweepLabelY)

fig.subplots_adjust(hspace=.4)  # add more space between the subplots

plt.show()

# %% [markdown]
# #### References:
# https://www.geeksforgeeks.org/working-images-python/
# https://pypi.org/project/pyabf/
# https://github.com/swharden/pyABF/tree/master/docs/getting-started
# http://jeakwon.blogspot.com/2018/07/reading-raw-abf-files-in-python-pyabf.html
