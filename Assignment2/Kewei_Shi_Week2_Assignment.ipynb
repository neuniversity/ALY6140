# %% [markdown]
# ALY6140 Week2 Assignment
#
# Written by Kewei Shi
#
# Assignment 2 Steps:
# 1. Create a Jupyter notebook file;
# 2. Write codes to read different example files (Example_Image, Example_Csv, Example_Excel, Example_Binary);
# 3. write functions to manipulate read files;
# 4. Provide explanation about each file in a markdown section;
# 5. Submit assignment to github branch.

# %%
import PIL
from PIL import Image, ImageFilter     
image = Image.open('Nuclei_Msk.jpg')     #Read image
image.show()     #Display image

# %%
import PIL
from PIL import Image, ImageFilter     
image_gray = Image.open('Nuclei_Msk.jpg').convert('L')     #Read image and turn it into grayscale
image_gray.show()     #Display image

# %%
import PIL
from PIL import Image
image = Image.open('Nuclei_Msk.jpg')
image_2 = image.rotate(180)     #Rotate image by 180 degrees
image_2.show()     #Display image

# %%
import pandas as pd     #Import useful library
csvdf = pd.read_csv('Nuclei.csv')     #Read CSV file
csvdf.head(n=10)   #Display the first 10 rows of CSV file
# Out:
#    ImageNumber  ObjectNumber  Intensity_IntegratedIntensityEdge_DAPI  \
# 0            1             1                                5.066987
# 1            1             2                                4.461616
# 2            1             3                                4.838346
# 3            1             4                                3.235828
# 4            1             5                                3.967391
# 5            1             6                                3.642588
# 6            1             7                                4.316793
# 7            1             8                                4.867002
# 8            1             9                                3.629191
# 9            1            10                                5.247822
#
#    Intensity_IntegratedIntensityEdge_PI  Intensity_IntegratedIntensity_DAPI  \
# 0                              4.504585                           63.661448
# 1                              3.758312                           52.943389
# 2                              2.810544                           31.127337
# 3                              3.306371                           38.797894
# 4                              3.223301                           37.443107
# 5                              3.405142                           41.364141
# 6                              4.477180                           31.367926
# 7                              4.065171                           76.837522
# 8                              3.643809                           38.937820
# 9                              4.037842                           50.699672
#
#    Intensity_IntegratedIntensity_PI  Intensity_LowerQuartileIntensity_DAPI  \
# 0                         26.980835                               0.060006
# 1                         20.978958                               0.055276
# 2                         12.375784                               0.064607
# 3                         18.318380                               0.040070
# 4                         15.369772                               0.056352
# 5                         16.970337                               0.044755
# 6                         23.820432                               0.041352
# 7                         25.455009                               0.060227
# 8                         19.525383                               0.049371
# 9                         22.240864                               0.055512
#
#    Intensity_LowerQuartileIntensity_PI  Intensity_MADIntensity_DAPI  \
# 0                             0.035172                     0.019913
# 1                             0.033928                     0.033433
# 2                             0.030098                     0.014519
# 3                             0.032624                     0.028779
# 4                             0.032898                     0.027031
# 5                             0.032547                     0.034653
# 6                             0.034897                     0.006256
# 7                             0.033768                     0.044175
# 8                             0.033719                     0.016052
# 9                             0.033833                     0.024109
#
#    Intensity_MADIntensity_PI          ...           \
# 0                   0.001007          ...
# 1                   0.001694          ...
# 2                   0.000992          ...
# 3                   0.000977          ...
# 4                   0.001404          ...
# 5                   0.001190          ...
# 6                   0.000870          ...
# 7                   0.001801          ...
# 8                   0.000931          ...
# 9                   0.001350          ...
#
#    Intensity_MinIntensityEdge_PI  Intensity_MinIntensity_DAPI  \
# 0                       0.031388                     0.031815
# 1                       0.028016                     0.029816
# 2                       0.027512                     0.038941
# 3                       0.028748                     0.026749
# 4                       0.028244                     0.031708
# 5                       0.030655                     0.028626
# 6                       0.032563                     0.026078
# 7                       0.027161                     0.031449
# 8                       0.031189                     0.026932
# 9                       0.029801                     0.033814
#
#    Intensity_MinIntensity_PI  Intensity_StdIntensityEdge_DAPI  \
# 0                   0.031388                         0.005757
# 1                   0.027481                         0.005620
# 2                   0.027512                         0.007579
# 3                   0.028748                         0.003096
# 4                   0.028153                         0.005773
# 5                   0.029587                         0.004644
# 6                   0.032166                         0.007047
# 7                   0.027161                         0.006060
# 8                   0.031006                         0.004834
# 9                   0.029801                         0.005416
#
#    Intensity_StdIntensityEdge_PI  Intensity_StdIntensity_DAPI  \
# 0                       0.001566                     0.029094
# 1                       0.002464                     0.036908
# 2                       0.001566                     0.019099
# 3                       0.001483                     0.030482
# 4                       0.002650                     0.030331
# 5                       0.001792                     0.037384
# 6                       0.001322                     0.009035
# 7                       0.002904                     0.049777
# 8                       0.001657                     0.023147
# 9                       0.001868                     0.027369
#
#    Intensity_StdIntensity_PI  Intensity_UpperQuartileIntensity_DAPI  \
# 0                   0.001507                               0.107881
# 1                   0.002593                               0.121820
# 2                   0.001467                               0.092367
# 3                   0.001442                               0.096674
# 4                   0.002118                               0.110895
# 5                   0.001684                               0.113855
# 6                   0.001290                               0.053887
# 7                   0.002442                               0.149538
# 8                   0.001468                               0.086091
# 9                   0.001969                               0.103613
#
#    Intensity_UpperQuartileIntensity_PI  Number_Object_Number
# 0                             0.037224                     1
# 1                             0.037316                     2
# 2                             0.032090                     3
# 3                             0.034585                     4
# 4                             0.035672                     5
# 5                             0.034943                     6
# 6                             0.036652                     7
# 7                             0.037415                     8
# 8                             0.035573                     9
# 9                             0.036481                    10
#
# [10 rows x 33 columns]

# %%
import pandas as pd     #Import useful library
csvdf = pd.read_csv('Nuclei.csv')     #Read CSV file
csvdf_sorted = csvdf.sort_values('Intensity_IntegratedIntensityEdge_DAPI') #Sort CSV file by 'Intensity_IntegratedIntensityEdge_DAPI'
csvdf_sorted.head(n = 10)
# Out:
#      ImageNumber  ObjectNumber  Intensity_IntegratedIntensityEdge_DAPI  \
# 211            1           212                                1.969421
# 202            1           203                                2.088533
# 179            1           180                                2.255039
# 101            1           102                                2.584451
# 57             1            58                                2.651728
# 423            1           424                                2.768307
# 735            1           736                                2.769375
# 298            1           299                                2.807324
# 234            1           235                                2.838926
# 226            1           227                                2.849622
#
#      Intensity_IntegratedIntensityEdge_PI  Intensity_IntegratedIntensity_DAPI  \
# 211                              8.995270                            9.186450
# 202                              1.346761                            5.255940
# 179                              1.249378                            4.785382
# 101                              2.136446                           14.059312
# 57                               1.974212                           12.642008
# 423                              1.188937                            5.841093
# 735                              1.482063                            7.801587
# 298                              1.484504                            6.139361
# 234                              2.120439                           16.849393
# 226                              1.545815                            8.378119
#
#      Intensity_IntegratedIntensity_PI  Intensity_LowerQuartileIntensity_DAPI  \
# 211                         45.410727                               0.042176
# 202                          2.954543                               0.049821
# 179                          2.692988                               0.039982
# 101                          7.687007                               0.041779
# 57                           6.587839                               0.045380
# 423                          2.322469                               0.050217
# 735                          3.447959                               0.063645
# 298                          3.060929                               0.054543
# 234                          8.049546                               0.043473
# 226                          3.916670                               0.054746
#
#      Intensity_LowerQuartileIntensity_PI  Intensity_MADIntensity_DAPI  \
# 211                             0.191546                     0.017136
# 202                             0.031373                     0.008774
# 179                             0.029492                     0.013138
# 101                             0.031392                     0.015251
# 57                              0.029313                     0.012589
# 423                             0.028412                     0.020813
# 735                             0.032746                     0.011444
# 298                             0.033577                     0.012001
# 234                             0.030213                     0.021302
# 226                             0.029915                     0.010986
#
#      Intensity_MADIntensity_PI          ...           \
# 211                   0.108186          ...
# 202                   0.000839          ...
# 179                   0.001419          ...
# 101                   0.000969          ...
# 57                    0.001129          ...
# 423                   0.000595          ...
# 735                   0.001053          ...
# 298                   0.000755          ...
# 234                   0.001129          ...
# 226                   0.000885          ...
#
#      Intensity_MinIntensityEdge_PI  Intensity_MinIntensity_DAPI  \
# 211                       0.092317                     0.032853
# 202                       0.029389                     0.032456
# 179                       0.025742                     0.026627
# 101                       0.029526                     0.026215
# 57                        0.026581                     0.032410
# 423                       0.026749                     0.034134
# 735                       0.030930                     0.037186
# 298                       0.031647                     0.033021
# 234                       0.027726                     0.028275
# 226                       0.027756                     0.032532
#
#      Intensity_MinIntensity_PI  Intensity_StdIntensityEdge_DAPI  \
# 211                   0.092317                         0.004332
# 202                   0.029175                         0.013532
# 179                   0.025742                         0.020094
# 101                   0.029526                         0.012454
# 57                    0.026581                         0.005858
# 423                   0.026749                         0.030204
# 735                   0.030930                         0.021521
# 298                   0.031647                         0.023984
# 234                   0.027726                         0.015672
# 226                   0.027756                         0.021907
#
#      Intensity_StdIntensityEdge_PI  Intensity_StdIntensity_DAPI  \
# 211                       0.057620                     0.025898
# 202                       0.001403                     0.012622
# 179                       0.002270                     0.016360
# 101                       0.001742                     0.018302
# 57                        0.001679                     0.015134
# 423                       0.001032                     0.025772
# 735                       0.001965                     0.020313
# 298                       0.001204                     0.018943
# 234                       0.002326                     0.023764
# 226                       0.001552                     0.017347
#
#      Intensity_StdIntensity_PI  Intensity_UpperQuartileIntensity_DAPI  \
# 211                   0.151269                               0.081880
# 202                   0.001346                               0.067033
# 179                   0.002054                               0.069005
# 101                   0.001396                               0.075074
# 57                    0.001563                               0.071000
# 423                   0.000976                               0.091768
# 735                   0.001703                               0.091791
# 298                   0.001127                               0.080682
# 234                   0.001805                               0.085893
# 226                   0.001262                               0.078309
#
#      Intensity_UpperQuartileIntensity_PI  Number_Object_Number
# 211                             0.428977                   212
# 202                             0.033127                   203
# 179                             0.032532                   180
# 101                             0.033307                   102
# 57                              0.031617                    58
# 423                             0.029587                   424
# 735                             0.034646                   736
# 298                             0.035073                   299
# 234                             0.032441                   235
# 226                             0.031682                   227
#
# [10 rows x 33 columns]

# %%
from pandas import ExcelWriter     #Import useful excel tools in pandas
from pandas import ExcelFile     #Import useful excel tools in pandas
exceldf = pd.read_excel('Financial Sample.xlsx', sheet_name='Sheet1')     #Read excel worksheet
exceldf_sorted = exceldf.sort_values('Units Sold') #Sort excel file by units sold
exceldf_sorted.head(n = 10)
# Out:
#             Segment  Country    Product Discount Band  Units Sold  \
# 634      Government   Canada    Montana          High       200.0
# 100  Small Business  Germany  Carretera           Low       214.0
# 132  Small Business  Germany        VTT           Low       214.0
# 194       Midmarket   Canada      Paseo           Low       218.0
# 466      Government  Germany      Paseo          High       241.0
# 473      Government  Germany       Velo          High       241.0
# 422       Midmarket   Mexico       Velo        Medium       245.0
# 359      Government   Canada      Paseo        Medium       257.0
# 137  Small Business  Germany   Amarilla           Low       259.0
# 638      Government   Mexico      Paseo          High       260.0
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 634                    5         350      70000.0    9800.00  60200.00
# 100                    3         300      64200.0    1284.00  62916.00
# 132                  250         300      64200.0    1284.00  62916.00
# 194                   10          15       3270.0     130.80   3139.20
# 466                   10          20       4820.0     482.00   4338.00
# 473                  120          20       4820.0     482.00   4338.00
# 422                  120          15       3675.0     330.75   3344.25
# 359                   10           7       1799.0     143.92   1655.08
# 137                  260         300      77700.0    1554.00  76146.00
# 638                   10          20       5200.0     728.00   4472.00
#
#         COGS    Profit       Date  Month Number Month Name  Year
# 634  52000.0   8200.00 2014-05-01             5        May  2014
# 100  53500.0   9416.00 2013-10-01            10    October  2013
# 132  53500.0   9416.00 2013-10-01            10    October  2013
# 194   2180.0    959.20 2014-09-01             9  September  2014
# 466   2410.0   1928.00 2014-10-01            10    October  2014
# 473   2410.0   1928.00 2014-10-01            10    October  2014
# 422   2450.0    894.25 2014-05-01             5        May  2014
# 359   1285.0    370.08 2014-05-01             5        May  2014
# 137  64750.0  11396.00 2014-03-01             3      March  2014
# 638   2600.0   1872.00 2014-02-01             2   February  2014

# %%
from pandas import ExcelWriter     #Import useful excel tools in pandas
from pandas import ExcelFile     #Import useful excel tools in pandas
exceldf = pd.read_excel('Financial Sample.xlsx', sheet_name='Sheet1')     #Read excel worksheet
exceldf_sorted2 = exceldf.sort_values('Units Sold') #Sort excel file by units sold
exceldf_sorted2.drop(['Country','Product','Discount Band',
                      'Segment','COGS','Discounts','Date','Month Number']
                     ,axis = 1, inplace = True)     #Drop unwanted rows
exceldf_sorted2.head(n = 10)
# Out:
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales     Sales  \
# 634       200.0                    5         350      70000.0  60200.00
# 100       214.0                    3         300      64200.0  62916.00
# 132       214.0                  250         300      64200.0  62916.00
# 194       218.0                   10          15       3270.0   3139.20
# 466       241.0                   10          20       4820.0   4338.00
# 473       241.0                  120          20       4820.0   4338.00
# 422       245.0                  120          15       3675.0   3344.25
# 359       257.0                   10           7       1799.0   1655.08
# 137       259.0                  260         300      77700.0  76146.00
# 638       260.0                   10          20       5200.0   4472.00
#
#        Profit Month Name  Year
# 634   8200.00        May  2014
# 100   9416.00    October  2013
# 132   9416.00    October  2013
# 194    959.20  September  2014
# 466   1928.00    October  2014
# 473   1928.00    October  2014
# 422    894.25        May  2014
# 359    370.08        May  2014
# 137  11396.00      March  2014
# 638   1872.00   February  2014

# %%
import pyabf     #Import useful package
abf = pyabf.ABF('16o03002.abf')     #Read .abf file
print(abf)     #Show .abf file information
# Out:
# ABF file (16o03002.abf) with 2 channels, 6 sweeps, and a total length of 0.10 min.

# %%
import pyabf
import matplotlib.pyplot as plot
abf_plot = pyabf.ABF('16o03002.abf')
abf.setSweep(0)
plot.figure(figsize=(10, 5))
plot.plot(abf.sweepX, abf.sweepY, lw=.5)
plot.show()     #Plot the first sweep of .abf file

# %%
import pyabf
abf = pyabf.ABF("16o03002.abf")

fig = plt.figure(figsize=(10, 5))

abf.setSweep(sweepNumber=0, channel=0)
ax1 = fig.add_subplot(211)
ax1.set_title(f"Channel {abf.sweepChannel+1}")
ax1.plot(abf.sweepX, abf.sweepY, lw=.5)
ax1.set_ylabel(abf.sweepLabelY)

abf.setSweep(sweepNumber=1, channel=0)
ax1 = fig.add_subplot(211)
ax1.set_title(f"Channel {abf.sweepChannel+1}")
ax1.plot(abf.sweepX, abf.sweepY, lw=.5)
ax1.set_ylabel(abf.sweepLabelY)

abf.setSweep(sweepNumber=2, channel=0)
ax1 = fig.add_subplot(211)
ax1.set_title(f"Channel {abf.sweepChannel+1}")
ax1.plot(abf.sweepX, abf.sweepY, lw=.5)
ax1.set_ylabel(abf.sweepLabelY)

abf.setSweep(sweepNumber=3, channel=0)
ax1 = fig.add_subplot(211)
ax1.set_title(f"Channel {abf.sweepChannel+1}")
ax1.plot(abf.sweepX, abf.sweepY, lw=.5)
ax1.set_ylabel(abf.sweepLabelY)

abf.setSweep(sweepNumber=4, channel=0)
ax1 = fig.add_subplot(211)
ax1.set_title(f"Channel {abf.sweepChannel+1}")
ax1.plot(abf.sweepX, abf.sweepY, lw=.5)
ax1.set_ylabel(abf.sweepLabelY)

abf.setSweep(sweepNumber=5, channel=0)
ax1 = fig.add_subplot(211)
ax1.set_title(f"Channel {abf.sweepChannel+1}")
ax1.plot(abf.sweepX, abf.sweepY, lw=.5)
ax1.set_ylabel(abf.sweepLabelY)

plt.show()

# %% [markdown]
# For sample image file, "image" is the original file read by Python using its remote location. "image_2" is the manipulated version of original file by 180-degree rotation. "image_gray" displays the original sample image in grayscale.
#
# For sample CSV file, "csvdf" lists the first ten rows of the original file. "csvdf_sorted" is generated by sorting original CSV file by "Intensity_IntegratedIntensityEdge_DAPI" in ascendeing order. Other information of the object, such corresponding object number and serial number in the worksheet are also shown in the manipulated CSV file;
#
# For sample worksheet file, "exceldf" displays the first ten rows of the worksheet. "exceldf_sorted" displays the first ten rows of the worksheet by top 10 of least units sold. Corresponding information including product type, manufactoring price and sale price are also included in the worksheet file. "exceldf_sorted2" displays the desired information about the least sold units, such as manufacture cost, sale price and profits.
#
# For the sample ABF file, "abf" shows the basic information, including the number of channels, sweeps and total length. "plot" displays the first sweep of the sample file. "plt" displays channel 1 plots for all 6 sweeps.
