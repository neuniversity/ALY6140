# %% [markdown]
# # Read and List CSV data

# %%
import pandas as pd    #import library
csvdf = pd.read_csv('Nuclei.csv') #read the file
csvdf_sorted =csvdf.sort_values('Intensity_IntegratedIntensityEdge_DAPI')
max= csvdf['Intensity_IntegratedIntensityEdge_DAPI'].max()
min= csvdf['Intensity_IntegratedIntensityEdge_DAPI'].min()
var = csvdf['Intensity_IntegratedIntensityEdge_DAPI'].var()
print ('The maximum value under Intensity_IntegratedIntensityEdge_DAPI column is {0}')
# Out:
# The maximum value under Intensity_IntegratedIntensityEdge_DAPI column is {0}

# %%
import pandas as pd    #import library
csv = pd.read_csv('Nuclei.csv')
csv.head(15) #pull out the first 15 data
# Out:
#     ImageNumber  ObjectNumber  Intensity_IntegratedIntensityEdge_DAPI  \
# 0             1             1                                5.066987
# 1             1             2                                4.461616
# 2             1             3                                4.838346
# 3             1             4                                3.235828
# 4             1             5                                3.967391
# 5             1             6                                3.642588
# 6             1             7                                4.316793
# 7             1             8                                4.867002
# 8             1             9                                3.629191
# 9             1            10                                5.247822
# 10            1            11                                5.795468
# 11            1            12                                5.457908
# ...

# %%
import matplotlib.pyplot as  plt
plt.figure(figsize=(8,4))
number1 = csv.loc[:,'Intensity_IntegratedIntensityEdge_PI'].head(10)
number2 = csv.loc[:,'Intensity_IntegratedIntensityEdge_DAPI'].head(10)

plt.boxplot([number1,number2])
plt.gca().set_xticklabels(['Intensity_IntegratedIntensityEdge_DAPI','Intensity_IntegratedIntensityEdge_PI'])
# Out:
# [Text(0,0,'Intensity_IntegratedIntensityEdge_DAPI'),
#  Text(0,0,'Intensity_IntegratedIntensityEdge_PI')]

# %%
import matplotlib.pyplot as  plt
plt.figure(figsize=(10,15))
number1 = csv.loc[:,'Intensity_IntegratedIntensityEdge_PI'].head(10)
number2 = csv.loc[:,'Intensity_IntegratedIntensityEdge_DAPI'].head(10)

plt.boxplot([number1,number2])
plt.gca().set_xticklabels(['Intensity_IntegratedIntensityEdge_DAPI','Intensity_IntegratedIntensityEdge_PI'])
# Out:
# [Text(0,0,'Intensity_IntegratedIntensityEdge_DAPI'),
#  Text(0,0,'Intensity_IntegratedIntensityEdge_PI')]

# %%
import matplotlib.pyplot as  plt
plt.figure(figsize=(10,10))
number1 = csv.loc[:,'Intensity_IntegratedIntensityEdge_PI'].head(10)
number2 = csv.loc[:,'Intensity_IntegratedIntensityEdge_DAPI'].head(10)

plt.boxplot([number1,number2])
plt.gca().set_xticklabels(['Intensity_IntegratedIntensityEdge_DAPI','Intensity_IntegratedIntensityEdge_PI'])
# Out:
# [Text(0,0,'Intensity_IntegratedIntensityEdge_DAPI'),
#  Text(0,0,'Intensity_IntegratedIntensityEdge_PI')]
